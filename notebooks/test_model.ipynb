# %%
import ollama
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

load_dotenv("D:\Study Material\Sem-6\Mini Project\HLSS-v3\.env")
# Out:
# True

# %%
ollama_model = init_chat_model(model = "ministral-3:8b-cloud", model_provider = "ollama")

# %%
ollama_response = ollama_model.invoke("Hello, how are you?")

# %%
print("Ollama: ")
print(ollama_response)
# Out:
# Ollama:
# content="Hello! 😊 I'm just a virtual assistant, so I don't have feelings, but I'm here and ready to help you with anything you need! How about you—how are *you* doing today? Anything on your mind or something I can assist with?" additional_kwargs={} response_metadata={'model': 'ministral-3:8b', 'created_at': '2026-05-14T06:15:58.530296827Z', 'done': True, 'done_reason': 'stop', 'total_duration': 725330774, 'load_duration': None, 'prompt_eval_count': 9, 'prompt_eval_duration': None, 'eval_count': 57, 'eval_duration': None, 'logprobs': None, 'model_name': 'ministral-3:8b', 'model_provider': 'ollama'} id='lc_run--019e2520-a1f8-76c3-9bcd-2f32728ad925-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 9, 'output_tokens': 57, 'total_tokens': 66}
